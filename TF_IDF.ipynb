# %%
from sklearn.feature_extraction.text import TfidfVectorizer

documents = [
    "I dont care if it hurts",
    "I wanna have control",
    "I want a perfect body",
    "I want a perfect soul"
]

vectorizer = TfidfVectorizer()

X = vectorizer.fit_transform(documents)

print("Vocabulary: \n",vectorizer.get_feature_names_out())
print("Box Matrix:\n",X.toarray())
# Out:
# Vocabulary:
#  ['body' 'care' 'control' 'dont' 'have' 'hurts' 'if' 'it' 'perfect' 'soul'
#  'wanna' 'want']
# Box Matrix:
#  [[0.         0.4472136  0.         0.4472136  0.         0.4472136
#   0.4472136  0.4472136  0.         0.         0.         0.        ]
#  [0.         0.         0.57735027 0.         0.57735027 0.
#   0.         0.         0.         0.         0.57735027 0.        ]
#  [0.66767854 0.         0.         0.         0.         0.
#   0.         0.         0.52640543 0.         0.         0.52640543]
#  [0.         0.         0.         0.         0.         0.
#   0.         0.         0.52640543 0.66767854 0.         0.52640543]]
